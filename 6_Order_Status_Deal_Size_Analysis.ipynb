# %% [markdown]
# #🚚Order Status & Deal Size Analysis
#
# ###✅ Order Status Breakdown →
# ####Analyze the percentage of orders in Shipped, Cancelled, or On Hold statuses (STATUS)
# ###✅ Sales Contribution by Deal Size →
# ####Compare revenue contributions of Small, Medium, and Large deals (DEALSIZE)

# %% [markdown]
# ## 📂 Load the Dataset
# * We begin by loading the sales dataset to explore its structure and contents.

# %%
import pandas as pd               # Data manipulation
import matplotlib.pyplot as plt   # Visualization
import seaborn as sns             # Advanced plots

df=pd.read_csv("drive/MyDrive/Colab Notebooks/Data.csv")
print(df.head())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %% [markdown]
# #🔥Order Status Breakdown
# ####✅You can calculate the percentage of orders in each STATUS (e.g., Shipped, Cancelled, On Hold) and plot a pie chart for a quick overview.

# %%
# Order Status Breakdown (Bar Graph)
status_counts = df['STATUS'].value_counts()
status_percentage = (status_counts / status_counts.sum()) * 100  # Convert to percentage

# Convert to DataFrame for plotting
status_df = pd.DataFrame({'STATUS': status_percentage.index, 'PERCENTAGE': status_percentage.values})

# Plot: Order Status Breakdown (Fixed Bar Chart)
plt.figure(figsize=(10,6))
sns.barplot(x='STATUS', y='PERCENTAGE', data=status_df, hue='STATUS', dodge=False, palette='Set2', legend=False)

plt.title('Order Status Breakdown')
plt.xlabel('Order Status')
plt.ylabel('Percentage of Orders (%)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #🔥Sales Contribution by Deal Size
# ####✅You can calculate the total SALES for each DEALSIZE category (Small, Medium, Large) and plot a bar chart to show the contribution of each deal size to the total sales.

# %%
# ✅ Sales Contribution by Deal Size (Bar Chart)
deal_size_sales = df.groupby('DEALSIZE')['SALES'].sum().reset_index()
deal_size_sales['SALES'] = deal_size_sales['SALES'] / 1e5

# Plot: Sales Contribution by Deal Size
plt.figure(figsize=(10,6))
sns.barplot(x='DEALSIZE', y='SALES',hue='DEALSIZE',data=deal_size_sales, palette='coolwarm')
plt.title('Sales Contribution by Deal Size')
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('Deal Size')
plt.ylabel('Total Sales (in Lakhs)')
plt.show()
