# %% [markdown]
# # 🏆 Products Performance Analysis
#
# ## 📝 Overview
#
# ### This notebook analyzes the **performance of different product lines** based on their contribution to total sales.
# ## By identifying the **best and least-performing products**, we can gain insights into:
#
# ####✅ **Analyzing Product Contribution to Sales**
# ####✅ **Least Contributing Products and Possible Reasons** 📉
# ####✅ **Sales Distribution Across Different Product Lines**
#
# ####Understanding these insights helps businesses **optimize product strategies, pricing, and marketing efforts** to improve overall sales performance.

# %% [markdown]
# ## 📂 Load the Dataset
# * We begin by loading the sales dataset to explore its structure and contents.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("drive/MyDrive/Colab Notebooks/Data.csv")

# Display first few rows
print(df.head())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %% [markdown]
# #📊 Analyzing Product Contribution to Sales
#
# ###To evaluate **product performance**, we analyze total sales across different product lines.
# This helps in understanding:
#
# ####✅ Which **product lines drive the most revenue** 📈
# ####✅ Which **products contribute the least to overall sales** 📉
#
# ####By visualizing this data, businesses can focus on **high-performing products** and improve strategies for the **low-performing ones**.

# %%
# Analyzing Products Contribution to Sales

# Group by Product Line and sum total sales
Top_Products = df.groupby("PRODUCTLINE")["SALES"].sum().sort_values(ascending=False) / 1e5

# Set figure size
plt.figure(figsize=(10, 5))

# Create a bar plot
Top_Products.plot(kind="bar", color="teal")

# Add title and labels
plt.title("Top Revenue-Generating Product Categories", fontsize=14, fontweight="bold")
plt.xlabel("Product Line")
plt.ylabel("Total Sales (in Lakhs)")

# Display the plot
plt.show()

# %% [markdown]
# # 📉 Least Contributing Products – Insights & Possible Reasons
#
# ### From the **product performance analysis**, we observe that some product lines contribute **significantly less** to overall sales.
#
# ## ❗ Possible Reasons for Low Sales:
# ####✅ **Market Demand:** Certain products may have lower demand in the market.
# ####✅ **Pricing Strategy:** Higher prices compared to competitors could reduce sales.
# ####✅ **Limited Availability:** Stock shortages or limited regional availability.
# ####✅ **Marketing & Promotion:** Lack of effective promotions or advertising.
#
# ##🔹 Recommendations to Improve Sales:
# ####✅ **Adjust Pricing** based on competitor analysis and market demand.
# ####✅ **Increase Marketing Efforts** through promotions, discounts, and campaigns.
# ####✅ **Expand Availability** in regions with potential demand.
# ####✅ **Customer Feedback Analysis** to identify improvements for low-selling products.

# %% [markdown]
# # 📊 Sales Distribution Across Different Product Lines
#
# #### Understanding the **sales distribution** across different product lines helps in identifying which categories generate the highest revenue and which contribute the least.
#
# ## By visualizing this distribution, we can:
#
# ####✅ Determine **which product lines dominate sales** 📈
# ####✅ Identify **less contributing product lines** 📉
# ####✅ Help businesses focus on **high-performing categories** while improving weaker ones
#
# ####We use **pie charts and bar charts** to represent the proportion of total sales contributed by each product line. This provides a **clear visual breakdown** of sales across categories.

# %%
# Group Sales by Product Line
Sales_Distribution=df.groupby("PRODUCTLINE")["SALES"].sum()

# Plot Pie Chart for Distribution
Sales_Distribution.plot(kind="pie",autopct="%1.1f%%", colors=["#ff9999","#66b3ff","#99ff99","#ffcc99","#c2c2f0","#ffb3e6","#c4e17f"])

# Add Title
plt.title("Sales DIrtribution Across Product Lines")

# Display the plot
plt.ylabel("")  # Remove default y-label
plt.show()
